# %%
# What is Module

# %%
# it is the collection of classes, methods/functions and variables as python script

# it was saved with .py extention

# %%
# Three Types of Module

# 1) User define Module
# 2) Built in Module
# 3) Third party Module
