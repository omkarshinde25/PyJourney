# %%
print("Hello")
# Out:
# Hello

# %%
a=(1,2,3,4)
print(a)
# Out:
# (1, 2, 3, 4)

# %%
t1=()
t2=(1,4,5,44,33,66,76)
t3=(1.2,33,True,3e4,"Omkar")

print("Empty Tuple",t1)
print("Integer Tuple",t2)
print("Mixed Tuple",t3)
# Out:
# Empty Tuple ()
# Integer Tuple (1, 4, 5, 44, 33, 66, 76)
# Mixed Tuple (1.2, 33, True, 30000.0, 'Omkar')

# %%
# tuole are create using ()

# %%
# Tuples is index collection

# %%
t1=(89,33,22,45,66)
print(t1[1])  # Postive indexing
# Out:
# 33

# %%
print(t1[-1]) # Negative indexing
# Out:
# 66

# %%
# Tuples are ordered collection maintaon fixed order

# %%
# Tuples are immutable object

# %%
t1=(2,3,4,5,6,7)
print(t1)

t1[2]=33
# Out:
# (2, 3, 4, 5, 6, 7)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 t1=(2,3,4,5,6,7)
#       2 print(t1)
# ----> 4 t1[2]=33
#
# TypeError: 'tuple' object does not support item assignment

# %%
l1=[1,2,3,4,5]
l1[2]=33
print(l1)
# Out:
# [1, 2, 33, 4, 5]

# %%
l2=list(t1)

l2[2]=33

t1=tuple(l2)

print(t1)
# Out:
# (2, 3, 33, 5, 6, 7)

# %%
t1=(1,2,3,4)
t2=(5,6,7,8)
t1=t1+t2
print(t1)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8)

# %%
t2=(5,6,7,8)
t2=t2*3
print(t2)
# Out:
# (5, 6, 7, 8, 5, 6, 7, 8, 5, 6, 7, 8)

# %%
# tuple allow the duplicated data

# %%
# interating throgh tuple using for loop and while loop

# %%
t=("Apple","Greaps","Oranage","Mango","Kiwi")

for i in t:
    print(i)
# Out:
# Apple
# Greaps
# Oranage
# Mango
# Kiwi

# %%
for i in t:
    print(i,"Fruits")
# Out:
# Apple Fruits
# Greaps Fruits
# Oranage Fruits
# Mango Fruits
# Kiwi Fruits

# %%
# Built in method for tuple

# count - count the accuranace of element preset in a tuple
# index - return the index

# %%
t1=(12,67)
t1=t1*5
print("Original Tuple",t1)


print("Count of the 12",t1.count(12))
# Out:
# Original Tuple (12, 67, 12, 67, 12, 67, 12, 67, 12, 67)
# Count of the 12 5

# %%
print("Index of 12-",t1.index(12))
# Out:
# Index of 12- 0

# %%
print("Index of 67:",t1.index(67))
# Out:
# Index of 67: 1

# %%
# if they repeted value and index is fist occurance

# %%
# Index method with start and end

# %%
print("Index of 12 between 1 and 3-",t1.index(12,1,7))
# Out:
# Index of 12 between 1 and 3- 2

# %%
print("Len of t1:",len(l1)) # Lenght function
# Out:
# Len of t1: 5

# %%
print("max in t1",max(t1))  # max in tuple
# Out:
# max in t1 67

# %%
print("min in tuple",min(t1))  # min in tuple
# Out:
# min in tuple 12
