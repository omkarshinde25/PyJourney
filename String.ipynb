# %%
# Strung - sequence of characters

# %%
# immutable - can not change string original string

# %%
# Ordered Collection

# %%
# Support Support slicing to extract sub string

# %%
# string is iterable

# %%
# strings are having dyanamic lenght

# %%
# String can hold any type character like - number,letter,symbols

# %%
a= 'Hello'

# %%
b="Hello"

# %%
c='''Helllo My Name is Omkar Shinde'''

# %%
# There are two types of indexing

# %%
# Postive indexing - start with 0

# %%
# Negative indexing - start with -1

# %%
s1='Omkar'
s2="Shinde"
s3='''I have completed my B Tech dgree.
I have skills python and sql'''

print(s1)
print(s2)
print(s3)
# Out:
# Omkar
# Shinde
# I have completed my B Tech dgree.
# I have skills python and sql

# %%
print(type(s1))
print(type(s2))
print(type(s3))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
# Indexing

# %%
s1="FortuneCloud"

# %%
s1[0]
# Out:
# 'F'

# %%
s1[7]
# Out:
# 'C'

# %%
s1[-2]
# Out:
# 'u'

# %%
s1[-3]
# Out:
# 'o'

# %%
s1[2]
# Out:
# 'r'

# %%
S2="Omkar"

# %%
S2[0]
# Out:
# 'O'

# %%
S2[1]
# Out:
# 'm'

# %%
S2[2]
# Out:
# 'k'

# %%
S2[3]
# Out:
# 'a'

# %%
S2[4]
# Out:
# 'r'

# %%
# S2[5] - IndexError: string index out of range

# %%
# S2[1.1] - TypeError: string indices must be integers, not 'float'

# %%
# Slicing - Indexing

# %%
s1="FortuneCloud"

# %%
s1[0:12]
# Out:
# 'FortuneCloud'

# %%
s1[:7]
# Out:
# 'Fortune'

# %%
s1[7:]
# Out:
# 'Cloud'

# %%
s1[::-1]
# Out:
# 'duolCenutroF'

# %%
s2="OmkarShinde"

# %%
s2[0:12]
# Out:
# 'OmkarShinde'

# %%
s2[:5]
# Out:
# 'Omkar'

# %%
s2[5:]
# Out:
# 'Shinde'

# %%
s2[::-1]
# Out:
# 'ednihSrakmO'

# %%
s2[0:12:2]
# Out:
# 'Okrhne'

# %%
s="Computer"

# %%
s[0:4]
# Out:
# 'Comp'

# %%
s[4:]
# Out:
# 'uter'

# %%
s[3:6]
# Out:
# 'put'

# %%
s[0:9:2]
# Out:
# 'Cmue'

# %%
s[::2]
# Out:
# 'Cmue'

# %%
s[1:9:2]
# Out:
# 'optr'

# %%
s[1::2]
# Out:
# 'optr'

# %%
s[-3:]
# Out:
# 'ter'

# %%
# s1="Hello"                        # Can not change original string
# s1[1]='a'
# print(s1)

# %%
s1="fortunecloud"

print("Origunal String s1: ",s1)

s1="F"+s1[1:7]+"C"+s1[8:]

print("Modified String s1:",s1)
# Out:
# Origunal String s1:  fortunecloud
# Modified String s1: FortuneCloud

# %%
# Len - Lenght function

# %%
s1='Omkar'

# %%
lenght=len(s1)

# %%
print("No of characters in s1",lenght)
# Out:
# No of characters in s1 5

# %%
print(s1.upper())
# Out:
# OMKAR

# %%
print(s1.lower())
# Out:
# omkar

# %%
s2="  Aniket   "
print(s2)
print(s2.strip())      # remove white spaces from start to end
# Out:
#   Aniket
# Aniket

# %%
# replace ("Sub string to replace","new string to be added")

s1="Learning python is fun"

print(s1)

print(s1.replace("fun",'Amzing'))
# Out:
# Learning python is fun
# Learning python is Amzing

# %%
# concatention - join two string

s1="Fortune"

s2="Cloud"

s3=s1+" "+s2

print(s3)
# Out:
# Fortune Cloud

# %%
s1="Omkar"

s2="Shinde"

s3=s1+ "_"+ s2
print(s3)
# Out:
# Omkar_Shinde

# %%
# Repeted String

s1="Hello"

s2=s1*3

print(s2)
# Out:
# HelloHelloHello

# %%
name="Sam"
age=22
live="Pune"

print(f"{name} is a {age} year old man living in a city {live}")
# Out:
# Sam is a 22 year old man living in a city Pune

# %%
emp_name="Bill"
company="Tata"
year=2007

print(f"{emp_name} is working in {company} since {year}")
# Out:
# Bill is working in Tata since 2007

# %%
# format()

# %%
name="Omkar"
role="Software Developer"
company="Apple"

s1="{} is {} at {}.".format(name,role,company)

print(s1)
# Out:
# Omkar is Software Developer at Apple.

# %%
# Membership Test String

# %%
s1="Welcome"
print("e is part of s1", 'e' in s1)
# Out:
# e is part of s1 True

# %%
s = "swiss"

for ch in s:
    if s.count(ch) == 1:
        print("First non-repeated character:", ch)
        break
# Out:
# First non-repeated character: w

# %%
s = "programming"

for ch in s:
    if s.count(ch) == 1:
        print(ch, end=" ")
# Out:
# p o a i n

# %%
o="Omkar"

for i in o:
    if o.count(i)==1:
        print(i, end=" ")
# Out:
# O m k a r

# %%
n="nitin"

for i in n:
    if n.count(i)==1:
        print(i,end=" ")
# Out:
# t
