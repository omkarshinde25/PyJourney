# %%
# Varibles

# %%
# varibale in python it is like container it is stored data or value
# python programming language is dyanamic langauge its not define data type in variable
# varible assign the value using the assignment operator

# %%
# There are 5 Rules
# 1. varible is a create to be A to Z, a to z, 0 to 9, _ (underscore)
# 2. varible start with _ and latter
# 3 varible is not allow to space
# 4 variable is case sentive
# 5 varibale can not use the predifine keywords in python

# %%
a= 2

# %%
print(a)
# Out:
# 2

# %%
var= 10
print(var)
# Out:
# 10

# %%
# dyanamic Typing

# %%
a = 10

# %%
print(a)
# Out:
# 10

# %%
a = "Omkar"

# %%
print(a)
# Out:
# Omkar

# %%
# multiple time use the assign the same varible in  python

# %%
var1= 12
print(var1)
var1='Welcome'
print(var1)
var1=[1,2,3]
print(var1)
# Out:
# 12
# Welcome
# [1, 2, 3]

# %%
# Multiple variables assign at one time

# %%
var=var1=var2=22
print(var)
print(var1)
print(var2)
# Out:
# 22
# 22
# 22

# %%
print(type(var1))
# Out:
# <class 'int'>

# %%
# Assigning different values to multiple variblaes

# %%
var1,var2,var3= 10250,"Monday",2

# %%
print(var1)
print(var2)
print(var3)
# Out:
# 10250
# Monday
# 2

# %%
# Type Casting

# %%
# 1 Implicit Casting

var1= 9
var2=var1/4
print(var2)
# Out:
# 2.25

# %%
print(type(var2))
# Out:
# <class 'float'>

# %%
# 2 Explicit Casting

var2 = int(var2)
print(var2)
# Out:
# 2

# %%
print(type(var2))
# Out:
# <class 'int'>

# %%
a=10
b=3
c=a+b
print(c)
# Out:
# 13

# %%
x=5
x=x+2
print(x)
# Out:
# 7

# %%
name = "Omkar"
age= 22
print(name,age)
# Out:
# Omkar 22

# %%
a = "10"
b = 20

print(int(a) + b)
print(a * 2)
# Out:
# 30
# 1010

# %%
name= "Python"
version= 3.12
print(name,version)
# Out:
# Python 3.12

# %%
a=10
a=20
print(a)
# Out:
# 20

# %%
x=5
y=x
x=10
print(y)
# Out:
# 5

# %%
a,b,c=10,20,30
print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %%
a=b=c=100
print(a)
print(b)
print(c)
# Out:
# 100
# 100
# 100

# %%
# swaping vaiables

# %%
a=10
b=20

a,b=b,a

print("a",a)
print("b",b)
# Out:
# a 20
# b 10

# %%
a=10
b="10"
print(type(a),type(b))
# Out:
# <class 'int'> <class 'str'>

# %%
x=2
y=2.5
z=x+y        # Implicit Type Casting Automatic by python

print(z)
print(type(z))
# Out:
# 4.5
# <class 'float'>

# %%
z=int(z)
print(type(z))
# Out:
# <class 'int'>

# %%
a=10
b=a
a=15
print("a",a)
print("b",b)
# Out:
# a 15
# b 10

# %%
x=10
print(id(x))
x=10
print(id(x))
# Out:
# 140705765766344
# 140705765766344

# %%
a=20
print(id(a))
# Out:
# 140705765766664

# %%
a=5
b=5
print(a is b)
# Out:
# True

# %%
x = "5"
y = "10"
print(x + y)
print(int(x) + int(y))
# Out:
# 510
# 15

# %%
x=y=z=50
z=100
print(x,y,z)
# Out:
# 50 50 100

# %%
x = 10
y = x
y += 5
print(x, y)
# Out:
# 10 15

# %%
# Global And Local Variable

# %%
x=10

def printdetails():
    y=20
    print("x Inside FUN",x)
    print("y Inside FUN",y)

printdetails()
print("x Outside FUN",x)
# Out:
# x Inside FUN 10
# y Inside FUN 20
# x Outside FUN 10

# %%
# Global varibale is x

# Global variable access the entire the program and also in class

# local variable is y

# local variable is defined the only function access

# scope of variable
# local scope and global scope

# %%
# del keyword

# %%
# - it will allow to delete variable created inside our python program

# %%
no1=30
print(no1)
del no1
# Out:
# 30
